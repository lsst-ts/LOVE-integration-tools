# %%
from lsst.ts import salobj
# Out:
# current_tai uses current_tai_from_utc; clock_gettime(CLOCK_TAI) is off by 37.0 seconds

# %%
r = salobj.Remote(salobj.Domain(), 'MTMount')
await r.start_task

evt = await r.evt_summaryState.aget()
state = salobj.State(evt.summaryState)
print(state)

if(state == salobj.State.STANDBY):
    await r.cmd_start.start(timeout=30)
    await r.cmd_enable.start(timeout=30)

evt = await r.evt_summaryState.aget()
state = salobj.State(evt.summaryState)
print(state)

events = [d for d in dir(r) if 'evt' in d]
telemetries = [d for d in dir(r) if 'tel' in d]
print(events, telemetries)

for e in events:
    print(e)
    evt_remote = getattr(r, e)
    data = evt_remote.get()
    print(data)

for t in telemetries:
    print(t)
    tel_remote = getattr(r, t)
    data = tel_remote.get()
    print(data)
# Out:
# State.ENABLED
# State.ENABLED
# ['evt_appliedSettingsMatchStart', 'evt_authList', 'evt_axesInPosition', 'evt_axesState', 'evt_cameraCableWrapFollowing', 'evt_cameraCableWrapState', 'evt_cameraCableWrapTarget', 'evt_connected', 'evt_error', 'evt_errorCode', 'evt_heartbeat', 'evt_logLevel', 'evt_logMessage', 'evt_settingVersions', 'evt_settingsApplied', 'evt_simulationMode', 'evt_softwareVersions', 'evt_summaryState', 'evt_target', 'evt_warning'] ['tel_azimuth', 'tel_azimuthDrives', 'tel_cameraCableWrap', 'tel_elevation', 'tel_elevationDrives']
# evt_appliedSettingsMatchStart
# None
# evt_authList
# private_revCode: 9a339f4a, private_sndStamp: 1625591008.310925, private_rcvStamp: 1625594589.3818822, private_seqNum: 1, private_identity: MTMount, private_origin: 537, private_host: 0, authorizedUsers: , nonAuthorizedCSCs: , priority: 0
# evt_axesInPosition
# None
# evt_axesState
# private_revCode: d7a268e6, private_sndStamp: 1625591045.4974597, private_rcvStamp: 1625594589.4559684, private_seqNum: 2, private_identity: MTMount, private_origin: 537, private_host: 0, elevation: 3, azimuth: 3, priority: 0
# evt_cameraCableWrapFollowing
# private_revCode: 0f78a291, private_sndStamp: 1625591008.3442783, private_rcvStamp: 1625594589.498258, private_seqNum: 1, private_identity: MTMount, private_origin: 537, private_host: 0, enabled: 1, priority: 0
# evt_cameraCableWrapState
# private_revCode: 1e0f8590, private_sndStamp: 1625591045.4978194, private_rcvStamp: 1625594589.537662, private_seqNum: 2, private_identity: MTMount, private_origin: 537, private_host: 0, state: 3, priority: 0
# evt_cameraCableWrapTarget
# private_revCode: 323ff8f6, private_sndStamp: 1625594589.3669593, private_rcvStamp: 1625594589.5916805, private_seqNum: 3516, private_identity: MTMount, private_origin: 537, private_host: 0, position: 0.0, velocity: 0.0, taiTime: 1625594589.3669033, priority: 0
# evt_connected
# private_revCode: 22a3edad, private_sndStamp: 1625591008.3444257, private_rcvStamp: 1625594589.631132, private_seqNum: 1, private_identity: MTMount, private_origin: 537, private_host: 0, command: True, replies: True, priority: 0
# evt_error
# None
# evt_errorCode
# None
# evt_heartbeat
# private_revCode: a499b5c4, private_sndStamp: 1625594589.3761895, private_rcvStamp: 1625594589.7538018, private_seqNum: 3554, private_identity: MTMount, private_origin: 537, private_host: 0, heartbeat: False, priority: 0
# evt_logLevel
# private_revCode: 711c3dce, private_sndStamp: 1625591008.3102689, private_rcvStamp: 1625594589.7880764, private_seqNum: 1, private_identity: MTMount, private_origin: 537, private_host: 0, level: 20, priority: 0
# evt_logMessage
# private_revCode: 0a83e8e8, private_sndStamp: 1625591008.309574, private_rcvStamp: 1625594589.8222268, private_seqNum: 1, private_identity: MTMount, private_origin: 537, private_host: 0, name: MTMount, level: 20, message: Read historical data in 0.03 sec, traceback: , filePath: /opt/lsst/tssw/ts_salobj/python/lsst/ts/salobj/sal_info.py, functionName: start, lineNumber: 688, process: 537, priority: 0
# evt_settingVersions
# private_revCode: e97cc0eb, private_sndStamp: 1625591008.334867, private_rcvStamp: 1625594589.8564942, private_seqNum: 1, private_identity: MTMount, private_origin: 537, private_host: 0, recommendedSettingsVersion: test_mtmount,, recommendedSettingsLabels: , settingsUrl: , priority: 0
# evt_settingsApplied
# None
# evt_simulationMode
# None
# evt_softwareVersions
# None
# evt_summaryState
# private_revCode: 6f0fcc02, private_sndStamp: 1625591044.8756518, private_rcvStamp: 1625594589.996901, private_seqNum: 3, private_identity: MTMount, private_origin: 537, private_host: 0, summaryState: 2, priority: 0
# evt_target
# private_revCode: 261ad639, private_sndStamp: 1625594589.3671765, private_rcvStamp: 1625594590.0427551, private_seqNum: 3516, private_identity: MTMount, private_origin: 537, private_host: 0, elevation: 0.0, elevationVelocity: 0.0, azimuth: 0.0, azimuthVelocity: 0.0, taiTime: 0.0, trackId: 0, tracksys: , radesys: , priority: 0
# evt_warning
# None
# tel_azimuth
# None
# tel_azimuthDrives
# None
# tel_cameraCableWrap
# None
# tel_elevation
# None
# tel_elevationDrives
# None

# %%
r = salobj.Remote(salobj.Domain(), 'MTRotator')
await r.start_task

evt = await r.evt_summaryState.aget()
state = salobj.State(evt.summaryState)
print(state)

if(state == salobj.State.STANDBY):
    await r.cmd_start.start(timeout=30)
    await r.cmd_enable.start(timeout=30)

evt = await r.evt_summaryState.aget()
state = salobj.State(evt.summaryState)
print(state)

events = [d for d in dir(r) if 'evt' in d]
telemetries = [d for d in dir(r) if 'tel' in d]
print(events, telemetries)

for e in events:
    print(e)
    evt_remote = getattr(r, e)
    data = evt_remote.get()
    print(data)

for t in telemetries:
    print(t)
    tel_remote = getattr(r, t)
    data = tel_remote.get()
    print(data)
# Out:
# State.ENABLED
# State.ENABLED
# ['evt_appliedSettingsMatchStart', 'evt_authList', 'evt_commandableByDDS', 'evt_configuration', 'evt_connected', 'evt_controllerState', 'evt_errorCode', 'evt_heartbeat', 'evt_inPosition', 'evt_interlock', 'evt_logLevel', 'evt_logMessage', 'evt_settingVersions', 'evt_settingsApplied', 'evt_simulationMode', 'evt_softwareVersions', 'evt_summaryState', 'evt_target', 'evt_tracking'] ['tel_ccwFollowingError', 'tel_electrical', 'tel_motors', 'tel_rotation']
# evt_appliedSettingsMatchStart
# None
# evt_authList
# private_revCode: 20003a7e, private_sndStamp: 1625591008.3210418, private_rcvStamp: 1625594626.9809945, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, authorizedUsers: , nonAuthorizedCSCs: , priority: 0
# evt_commandableByDDS
# None
# evt_configuration
# private_revCode: 701bc0ea, private_sndStamp: 1625591008.3451529, private_rcvStamp: 1625594627.052094, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, positionAngleUpperLimit: 90.0, velocityLimit: 3.0, accelerationLimit: 1.0, positionErrorThreshold: 0.0, positionAngleLowerLimit: -90.0, followingErrorThreshold: 0.1, trackingSuccessPositionThreshold: 0.01, trackingLostTimeout: 5.0, priority: 0
# evt_connected
# private_revCode: 88c5c225, private_sndStamp: 1625591008.3449783, private_rcvStamp: 1625594627.0869236, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, command: True, telemetry: True, priority: 0
# evt_controllerState
# private_revCode: 34874a27, private_sndStamp: 1625591008.345453, private_rcvStamp: 1625594627.126757, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, controllerState: 0, offlineSubstate: 1, enabledSubstate: 0, applicationStatus: 1024, priority: 0
# evt_errorCode
# None
# evt_heartbeat
# private_revCode: 3a397884, private_sndStamp: 1625594627.6739812, private_rcvStamp: 1625594627.6749833, private_seqNum: 3592, private_identity: MTRotator, private_origin: 537, private_host: 0, heartbeat: False, priority: 0
# evt_inPosition
# None
# evt_interlock
# private_revCode: b13deb11, private_sndStamp: 1625591008.3457003, private_rcvStamp: 1625594627.2874076, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, detail: Disengaged, priority: 0
# evt_logLevel
# private_revCode: 54f93697, private_sndStamp: 1625591008.3208256, private_rcvStamp: 1625594627.3226848, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, level: 20, priority: 0
# evt_logMessage
# private_revCode: ca78c427, private_sndStamp: 1625591008.3202322, private_rcvStamp: 1625594627.3588197, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, name: MTRotator, level: 20, message: Read historical data in 0.01 sec, traceback: , filePath: /opt/lsst/tssw/ts_salobj/python/lsst/ts/salobj/sal_info.py, functionName: start, lineNumber: 688, process: 537, priority: 0
# evt_settingVersions
# private_revCode: 36008079, private_sndStamp: 1625591008.3379638, private_rcvStamp: 1625594627.3937829, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, recommendedSettingsVersion: test_mtrotator,, recommendedSettingsLabels: , settingsUrl: , priority: 0
# evt_settingsApplied
# None
# evt_simulationMode
# None
# evt_softwareVersions
# None
# evt_summaryState
# private_revCode: d5db5aa4, private_sndStamp: 1625594612.628098, private_rcvStamp: 1625594627.5288122, private_seqNum: 3, private_identity: MTRotator, private_origin: 537, private_host: 0, summaryState: 2, priority: 0
# evt_target
# None
# evt_tracking
# private_revCode: 75fe69d5, private_sndStamp: 1625594613.5632753, private_rcvStamp: 1625594627.6035976, private_seqNum: 1, private_identity: MTRotator, private_origin: 537, private_host: 0, tracking: False, lost: False, noNewCommand: False, priority: 0
# tel_ccwFollowingError
# private_revCode: 86d64a2a, private_sndStamp: 1625594627.663691, private_rcvStamp: 1625594627.6639218, private_seqNum: 15, private_identity: MTRotator, private_origin: 537, private_host: 0, positionError: 0.0, velocityError: 0.0, timestamp: 1625594627.6636531
# tel_electrical
# None
# tel_motors
# None
# tel_rotation
# None

# %%
r = salobj.Remote(salobj.Domain(), 'MTM1M3')
await r.start_task

evt = await r.evt_summaryState.aget()
state = salobj.State(evt.summaryState)
print(state)

if(state == salobj.State.STANDBY):
    await r.cmd_start.start(timeout=30)
    await r.cmd_enable.start(timeout=30)

evt = await r.evt_summaryState.aget()
state = salobj.State(evt.summaryState)
print(state)

events = [d for d in dir(r) if 'evt' in d]
telemetries = [d for d in dir(r) if 'tel' in d]
print(events, telemetries)

for e in events:
    print(e)
    evt_remote = getattr(r, e)
    data = evt_remote.get()
    print(data)

for t in telemetries:
    print(t)
    tel_remote = getattr(r, t)
    data = tel_remote.get()
    print(data)
